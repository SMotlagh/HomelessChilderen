# %%
import pandas as pd

# %%
pwd
# Out:
# '/home/cloudera/beautipy/DataIncubatorSeq'

# %%
Homeless_SheleterNYC=pd.read_csv("~/Desktop/DHS_Daily_Report.csv")

# %%
Homeless_SheleterNYC.head()
# Out:
#   Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0     08/21/2013                    28359                      21314
# 1     08/22/2013                    28366                      21324
# 2     08/23/2013                    28257                      21291
# 3     08/24/2013                    28274                      21343
# 4     08/25/2013                    28458                      21400
#
#    Total Individuals in Shelter  Single Adult Men in Shelter  \
# 0                         49673                         7231
# 1                         49690                         7201
# 2                         49548                         7149
# 3                         49617                         7110
# 4                         49858                         7230
#
#    Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 0                           2710                            9941
# ...

# %%
Homeless_SheleterNYC.tail()
# Out:
#      Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 2034     04/26/2019                    37719                      20963
# 2035     04/27/2019                    37700                      20945
# 2036     04/28/2019                    37801                      20941
# 2037     04/29/2019                    37802                      20905
# 2038     04/30/2019                    37781                      20931
#
#       Total Individuals in Shelter  Single Adult Men in Shelter  \
# 2034                         58682                        12076
# 2035                         58645                        12050
# 2036                         58742                        12136
# 2037                         58707                        12142
# 2038                         58712                        12079
#
#       Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 2034                           4412                           16488
# ...

# %%
Homeless_SheleterNYC["Date of Census"]=pd.to_datetime(Homeless_SheleterNYC["Date of Census"])

# %%
Homeless_SheleterNYC.dtypes
# Out:
# Date of Census                                             datetime64[ns]
# Total Adults in Shelter                                             int64
# Total Children in Shelter                                           int64
# Total Individuals in Shelter                                        int64
# Single Adult Men in Shelter                                         int64
# Single Adult Women in Shelter                                       int64
# Total Single Adults in Shelter                                      int64
# Families with Children in Shelter                                   int64
# Adults in Families with Children in Shelter                         int64
# Children in Families with Children in Shelter                       int64
# Total Individuals in Families with Children in Shelter              int64
# Adult Families in Shelter                                           int64
# Individuals in Adult Families in Shelter                            int64
# ...

# %%
Homeless_SheleterNYC.isnull().any()
# Out:
# Date of Census                                             False
# Total Adults in Shelter                                    False
# Total Children in Shelter                                  False
# Total Individuals in Shelter                               False
# Single Adult Men in Shelter                                False
# Single Adult Women in Shelter                              False
# Total Single Adults in Shelter                             False
# Families with Children in Shelter                          False
# Adults in Families with Children in Shelter                False
# Children in Families with Children in Shelter              False
# Total Individuals in Families with Children in Shelter     False
# Adult Families in Shelter                                  False
# Individuals in Adult Families in Shelter                   False
# dtype: bool

# %%
Homeless_SheleterNYC.set_index("Date of Census",inplace=True,drop=True)

# %%
Homeless_SheleterNYC.sort_index(inplace=True)

# %%
Homeless_SheleterNYC.head()
# Out:
#                 Total Adults in Shelter  Total Children in Shelter  \
# Date of Census
# 2013-08-21                        28359                      21314
# 2013-08-22                        28366                      21324
# 2013-08-23                        28257                      21291
# 2013-08-24                        28274                      21343
# 2013-08-25                        28458                      21400
#
#                 Total Individuals in Shelter  Single Adult Men in Shelter  \
# Date of Census
# 2013-08-21                             49673                         7231
# 2013-08-22                             49690                         7201
# 2013-08-23                             49548                         7149
# 2013-08-24                             49617                         7110
# 2013-08-25                             49858                         7230
#
#                 Single Adult Women in Shelter  Total Single Adults in Shelter  \
# ...

# %%
Homeless_SheleterNYC.tail()
# Out:
#                 Total Adults in Shelter  Total Children in Shelter  \
# Date of Census
# 2019-04-26                        37719                      20963
# 2019-04-27                        37700                      20945
# 2019-04-28                        37801                      20941
# 2019-04-29                        37802                      20905
# 2019-04-30                        37781                      20931
#
#                 Total Individuals in Shelter  Single Adult Men in Shelter  \
# Date of Census
# 2019-04-26                             58682                        12076
# 2019-04-27                             58645                        12050
# 2019-04-28                             58742                        12136
# 2019-04-29                             58707                        12142
# 2019-04-30                             58712                        12079
#
#                 Single Adult Women in Shelter  Total Single Adults in Shelter  \
# ...

# %%
Homeless_SheleterNYC["MOY"]=Homeless_SheleterNYC.index.month

# %%
Homeless_SheleterNYC["Y"]=Homeless_SheleterNYC.index.year

# %%
Homeless_SheleterNYC["Y"].unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
len(Homeless_SheleterNYC)/5
# Out:
# 407.8

# %%
import numpy as np
SheleterNYC=Homeless_SheleterNYC.loc[np.logical_and(Homeless_SheleterNYC.index>="2014",Homeless_SheleterNYC.index<="2017")]

# %%
Homeless_SheleterNYC=SheleterNYC.copy()

# %%
len(Homeless_SheleterNYC)
# Out:
# 1077

# %%
Homeless_SheleterNYC.tail()
# Out:
#                 Total Adults in Shelter  Total Children in Shelter  \
# Date of Census
# 2016-12-28                        36784                      23403
# 2016-12-29                        36746                      23395
# 2016-12-30                        36609                      23334
# 2016-12-31                        36324                      23320
# 2017-01-01                        36560                      23335
#
#                 Total Individuals in Shelter  Single Adult Men in Shelter  \
# Date of Census
# 2016-12-28                             60187                         9824
# 2016-12-29                             60141                         9798
# 2016-12-30                             59943                         9738
# 2016-12-31                             59644                         9544
# 2017-01-01                             59895                         9713
#
#                 Single Adult Women in Shelter  Total Single Adults in Shelter  \
# ...

# %%
GroupedMOY=Homeless_SheleterNYC.groupby(["MOY","Y"]).mean()

# %%
Homeless_SheleterNYC.columns
# Out:
# Index(['Total Adults in Shelter', 'Total Children in Shelter',
#        'Total Individuals in Shelter', 'Single Adult Men in Shelter',
#        'Single Adult Women in Shelter', 'Total Single Adults in Shelter',
#        'Families with Children in Shelter',
#        'Adults in Families with Children in Shelter',
#        'Children in Families with Children in Shelter',
#        'Total Individuals in Families with Children in Shelter ',
#        'Adult Families in Shelter', 'Individuals in Adult Families in Shelter',
#        'MOY', 'Y'],
#       dtype='object')

# %%
GroupedMOY
# Out:
#           Total Adults in Shelter  Total Children in Shelter  \
# MOY Y
# 1   2014             29260.193548               22209.516129
#     2015             33556.531250               24974.312500
#     2016             34733.903226               23406.387097
#     2017             36560.000000               23335.000000
# 2   2014             29634.321429               22509.964286
#     2015             33651.962963               24582.925926
#     2016             34903.379310               23279.103448
# 3   2014             29685.700000               22548.766667
#     2015             33513.821429               24157.464286
#     2016             34946.774194               22900.387097
# 4   2014             29957.633333               22723.766667
#     2015             33274.103448               23721.413793
#     2016             35036.178571               22790.464286
# 5   2014             30214.290323               22883.709677
# ...

# %%
# %matplotlib notebook
ChildData=GroupedMOY[["Children in Families with Children in Shelter"]]
ChildData=ChildData.unstack(level=1)
ChildData.columns=["2014","2015","2016", "2017"]
ChildData.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Homeless_SheleterNYC.columns
# Out:
# Index(['Total Adults in Shelter', 'Total Children in Shelter',
#        'Total Individuals in Shelter', 'Single Adult Men in Shelter',
#        'Single Adult Women in Shelter', 'Total Single Adults in Shelter',
#        'Families with Children in Shelter',
#        'Adults in Families with Children in Shelter',
#        'Children in Families with Children in Shelter',
#        'Total Individuals in Families with Children in Shelter ',
#        'Adult Families in Shelter', 'Individuals in Adult Families in Shelter',
#        'MOY', 'Y'],
#       dtype='object')

# %%
ChildData
# Out:
#              2014          2015          2016     2017
# MOY
# 1    22209.516129  24974.312500  23406.387097  23335.0
# 2    22509.964286  24582.925926  23279.103448      NaN
# 3    22548.766667  24157.464286  22900.387097      NaN
# 4    22723.766667  23721.413793  22790.464286      NaN
# 5    22883.709677  23484.407407  22756.533333      NaN
# 6    23159.730769  23144.064516  22643.200000      NaN
# 7    23446.258065  22956.066667  22822.333333      NaN
# 8    23656.032258  23185.218750  23308.129032      NaN
# 9    24098.678571  23426.032258  23555.866667      NaN
# 10   24698.565217  23383.612903  23597.121212      NaN
# 11   25136.121212  23459.344828  23736.733333      NaN
# 12   25326.032258  23405.000000  23594.812500      NaN

# %%
DFWeather=pd.read_csv("~/Downloads/1725306.csv")

# %%
DFWeather.head()
# Out:
#        STATION                         NAME        DATE  PRCP  SNOW  SNWD  \
# 0  USW00094728  NY CITY CENTRAL PARK, NY US  2012-12-29  0.26   0.0   0.0
# 1  USW00094728  NY CITY CENTRAL PARK, NY US  2012-12-30  0.00   0.0   0.0
# 2  USW00094728  NY CITY CENTRAL PARK, NY US  2012-12-31  0.00   0.0   0.0
# 3  USW00094728  NY CITY CENTRAL PARK, NY US  2013-01-01  0.00   0.0   0.0
# 4  USW00094728  NY CITY CENTRAL PARK, NY US  2013-01-02  0.00   0.0   0.0
#
#    TAVG  TMAX  TMIN
# 0   NaN    34    30
# 1   NaN    34    28
# 2   NaN    38    28
# 3   NaN    40    26
# 4   NaN    33    22

# %%
DFWeather.DATE=pd.to_datetime(DFWeather.DATE)
DFWeather.set_index(DFWeather.DATE,inplace=True,drop=True)
DFWeather.sort_index(inplace=True)
DFWeather.tail()
# Out:
#                 STATION                         NAME       DATE  PRCP  SNOW  \
# DATE
# 2019-04-24  USW00094728  NY CITY CENTRAL PARK, NY US 2019-04-24  0.00   0.0
# 2019-04-25  USW00094728  NY CITY CENTRAL PARK, NY US 2019-04-25  0.02   0.0
# 2019-04-26  USW00094728  NY CITY CENTRAL PARK, NY US 2019-04-26  1.03   0.0
# 2019-04-27  USW00094728  NY CITY CENTRAL PARK, NY US 2019-04-27  0.07   0.0
# 2019-04-28  USW00094728  NY CITY CENTRAL PARK, NY US 2019-04-28  0.01   0.0
#
#             SNWD  TAVG  TMAX  TMIN
# DATE
# 2019-04-24   0.0   NaN    69    55
# 2019-04-25   0.0   NaN    66    48
# 2019-04-26   0.0   NaN    59    51
# 2019-04-27   0.0   NaN    58    47
# 2019-04-28   0.0   NaN    53    45

# %%
DFWeather["MOY"]=DFWeather.index.month

# %%
MonthlyHomless=Homeless_SheleterNYC.copy()

# %%
Homeless_SheleterNYC['iDX']=Homeless_SheleterNYC.index
# MonthlyHomless.index.year)#+"MonthlyHomless.index.month

# %%
Homeless_SheleterNYC['iDX']=Homeless_SheleterNYC['iDX'].map(lambda x: str(x.year)+'-'+(str(x.month).zfill(2)))

# %%
Homeless_SheleterNYC['iDX'].head()
# Out:
# Date of Census
# 2014-01-01    2014-01
# 2014-01-02    2014-01
# 2014-01-03    2014-01
# 2014-01-04    2014-01
# 2014-01-05    2014-01
# Name: iDX, dtype: object

# %%
Homeless_SheleterNYC.index.name='DATE'

# %%
DFWeather.head()
# Out:
#                 STATION                         NAME       DATE  PRCP  SNOW  \
# DATE
# 2012-12-29  USW00094728  NY CITY CENTRAL PARK, NY US 2012-12-29  0.26   0.0
# 2012-12-30  USW00094728  NY CITY CENTRAL PARK, NY US 2012-12-30  0.00   0.0
# 2012-12-31  USW00094728  NY CITY CENTRAL PARK, NY US 2012-12-31  0.00   0.0
# 2013-01-01  USW00094728  NY CITY CENTRAL PARK, NY US 2013-01-01  0.00   0.0
# 2013-01-02  USW00094728  NY CITY CENTRAL PARK, NY US 2013-01-02  0.00   0.0
#
#             SNWD  TAVG  TMAX  TMIN  MOY
# DATE
# 2012-12-29   0.0   NaN    34    30   12
# 2012-12-30   0.0   NaN    34    28   12
# 2012-12-31   0.0   NaN    38    28   12
# 2013-01-01   0.0   NaN    40    26    1
# 2013-01-02   0.0   NaN    33    22    1

# %%
Homeless_SheleterNYC.columns
# Out:
# Index(['Total Adults in Shelter', 'Total Children in Shelter',
#        'Total Individuals in Shelter', 'Single Adult Men in Shelter',
#        'Single Adult Women in Shelter', 'Total Single Adults in Shelter',
#        'Families with Children in Shelter',
#        'Adults in Families with Children in Shelter',
#        'Children in Families with Children in Shelter',
#        'Total Individuals in Families with Children in Shelter ',
#        'Adult Families in Shelter', 'Individuals in Adult Families in Shelter',
#        'MOY', 'Y', 'iDX'],
#       dtype='object')

# %%
Homeless_SheleterNYC.index.name="DATE"

# %%
DFWeather.head()
# Out:
#                 STATION                         NAME       DATE  PRCP  SNOW  \
# DATE
# 2012-12-29  USW00094728  NY CITY CENTRAL PARK, NY US 2012-12-29  0.26   0.0
# 2012-12-30  USW00094728  NY CITY CENTRAL PARK, NY US 2012-12-30  0.00   0.0
# 2012-12-31  USW00094728  NY CITY CENTRAL PARK, NY US 2012-12-31  0.00   0.0
# 2013-01-01  USW00094728  NY CITY CENTRAL PARK, NY US 2013-01-01  0.00   0.0
# 2013-01-02  USW00094728  NY CITY CENTRAL PARK, NY US 2013-01-02  0.00   0.0
#
#             SNWD  TAVG  TMAX  TMIN  MOY
# DATE
# 2012-12-29   0.0   NaN    34    30   12
# 2012-12-30   0.0   NaN    34    28   12
# 2012-12-31   0.0   NaN    38    28   12
# 2013-01-01   0.0   NaN    40    26    1
# 2013-01-02   0.0   NaN    33    22    1

# %%
DFWeather.tail()
# DFWeather.drop("DATE",axis=1,inplace=True)
# DFWeather.reset_index(inplace=True,drop=False)
# Homeless_SheleterNYC.drop("DATE",axis=1,inplace=True)

Homeless_SheleterNYC.reset_index(inplace=True,drop=False)

# %%
DFWeather.head()
# Out:
#                 STATION                         NAME       DATE  PRCP  SNOW  \
# DATE
# 2012-12-29  USW00094728  NY CITY CENTRAL PARK, NY US 2012-12-29  0.26   0.0
# 2012-12-30  USW00094728  NY CITY CENTRAL PARK, NY US 2012-12-30  0.00   0.0
# 2012-12-31  USW00094728  NY CITY CENTRAL PARK, NY US 2012-12-31  0.00   0.0
# 2013-01-01  USW00094728  NY CITY CENTRAL PARK, NY US 2013-01-01  0.00   0.0
# 2013-01-02  USW00094728  NY CITY CENTRAL PARK, NY US 2013-01-02  0.00   0.0
#
#             SNWD  TAVG  TMAX  TMIN  MOY
# DATE
# 2012-12-29   0.0   NaN    34    30   12
# 2012-12-30   0.0   NaN    34    28   12
# 2012-12-31   0.0   NaN    38    28   12
# 2013-01-01   0.0   NaN    40    26    1
# 2013-01-02   0.0   NaN    33    22    1

# %%
DFMrgedHomlessWeather=Homeless_SheleterNYC.merge(DFWeather,on="DATE",how="left")

# %%
DFMrgedHomlessWeather.tail()
# Out:
#            DATE  Total Adults in Shelter  Total Children in Shelter  \
# 1072 2016-12-28                    36784                      23403
# 1073 2016-12-29                    36746                      23395
# 1074 2016-12-30                    36609                      23334
# 1075 2016-12-31                    36324                      23320
# 1076 2017-01-01                    36560                      23335
#
#       Total Individuals in Shelter  Single Adult Men in Shelter  \
# 1072                         60187                         9824
# 1073                         60141                         9798
# 1074                         59943                         9738
# 1075                         59644                         9544
# 1076                         59895                         9713
#
#       Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 1072                           3798                           13622
# ...

# %%
# %matplotlib notebook
DFMrgedHomlessWeather.reset_index(inplace=True)
DFMrgedHomlessWeather.set_index("iDX",inplace=True)
DFIndicators=DFMrgedHomlessWeather[["Total Adults in Shelter"]].groupby(DFMrgedHomlessWeather.index).agg({"Total Adults in Shelter":"mean"})
DFIndicators.sort_index(inplace=True)
DFIndicators.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
DFMrgedHomlessWeather["ChilderenInFamily"]=DFMrgedHomlessWeather["Children in Families with Children in Shelter"]/DFMrgedHomlessWeather["Total Individuals in Families with Children in Shelter "]
DFMrgedHomlessWeather.reset_index(inplace=True)
DFMrgedHomlessWeather.set_index("iDX",inplace=True)
DFIndicators=DFMrgedHomlessWeather[["ChilderenInFamily"]].groupby(DFMrgedHomlessWeather.index).agg({"ChilderenInFamily":"mean"})
DFIndicators.sort_index(inplace=True)
DFIndicators.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [raw]
# This plot illustrates that number of children per family in shelters is constant over time.
# The implication is that  constant number of childerent per family indicate that either no more family homless is out or shelter excesses capacity does not let new families enter.

# %%
# %matplotlib notebook
DFMrgedHomlessWeather["Idicator"]=DFMrgedHomlessWeather["Total Individuals in Families with Children in Shelter "]/DFMrgedHomlessWeather["Total Individuals in Shelter"]
DFMrgedHomlessWeather.reset_index(inplace=True)
DFMrgedHomlessWeather.set_index("iDX",inplace=True)
DFIndicators=DFMrgedHomlessWeather[["Idicator"]].groupby(DFMrgedHomlessWeather.index).agg({"Idicator":"mean"})
DFIndicators.sort_index(inplace=True)
DFIndicators.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
DFMrgedHomlessWeather[["Idicator","PRCP"]].groupby(DFMrgedHomlessWeather.index).agg({"Idicator":"mean","PRCP":"mean"})
# Out:
#          Idicator      PRCP
# iDX
# 2014-01  0.724921  0.090000
# 2014-02  0.725414  0.195714
# 2014-03  0.726420  0.122333
# 2014-04  0.727734  0.261667
# 2014-05  0.729317  0.140968
# 2014-06  0.731328  0.158077
# 2014-07  0.731510  0.180323
# 2014-08  0.730708  0.072581
# 2014-09  0.729774  0.043214
# 2014-10  0.730649  0.243478
# 2014-11  0.730956  0.136667
# 2014-12  0.731087  0.194839
# 2015-01  0.725273  0.164062
# 2015-02  0.719119  0.072222
# 2015-03  0.715327  0.139643
# 2015-04  0.712788  0.024483
# 2015-05  0.711766  0.057037
# 2015-06  0.707992  0.154516
# 2015-07  0.706651  0.119667
# 2015-08  0.706966  0.073437
# 2015-09  0.706701  0.105806
# 2015-10  0.703331  0.126129
# 2015-11  0.701469  0.069310
# 2015-12  0.699662  0.152258
# 2016-01  0.697234  0.142258
# 2016-02  0.694596  0.151724
# 2016-03  0.690754  0.037742
# 2016-04  0.690135  0.048929
# 2016-05  0.690063  0.125000
# 2016-06  0.689076  0.086667
# 2016-07  0.692256  0.234000
# 2016-08  0.695568  0.063548
# ...

# %%
DFMrgedHomlessWeather["MOY"]=DFMrgedHomlessWeather.DATE.dt.month
AvgWeather=DFMrgedHomlessWeather[["MOY","TMAX","TMIN","SNWD","PRCP"]].groupby("MOY").mean()

# %%
AvgWeather.columns=["Avg"]+AvgWeather.columns

# %%
AvgWeather.columns
# Out:
# Index(['AvgTMAX', 'AvgTMIN', 'AvgSNWD', 'AvgPRCP'], dtype='object')

# %%
AvgWeather.reset_index(drop=False,inplace=True)

# %%
DFMrgedHomlessWeather.reset_index(drop=False)
DFMrgedHomlessWeather=DFMrgedHomlessWeather.merge(AvgWeather, on="MOY", how='left')

# %%
DFMrgedHomlessWeather.columns
# Out:
# Index(['index', 'DATE', 'Total Adults in Shelter', 'Total Children in Shelter',
#        'Total Individuals in Shelter', 'Single Adult Men in Shelter',
#        'Single Adult Women in Shelter', 'Total Single Adults in Shelter',
#        'Families with Children in Shelter',
#        'Adults in Families with Children in Shelter',
#        'Children in Families with Children in Shelter',
#        'Total Individuals in Families with Children in Shelter ',
#        'Adult Families in Shelter', 'Individuals in Adult Families in Shelter',
#        'MOY_x', 'Y', 'STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TAVG', 'TMAX',
#        'TMIN', 'MOY_y', 'ChilderenInFamily', 'Idicator', 'MOY', 'AvgTMAX',
#        'AvgTMIN', 'AvgSNWD', 'AvgPRCP'],
#       dtype='object')

# %%
DFMrgedHomlessWeather["PosDiff_TMax"]=DFMrgedHomlessWeather["AvgTMAX"]-DFMrgedHomlessWeather["TMAX"]
DFMrgedHomlessWeather["PosDiff_TMIN"]=DFMrgedHomlessWeather["AvgTMIN"]-DFMrgedHomlessWeather["TMIN"]
DFMrgedHomlessWeather["PosDiff_PRCP"]=DFMrgedHomlessWeather["PRCP"]-DFMrgedHomlessWeather["AvgPRCP"]
DFMrgedHomlessWeather["PosDiff_SNWD"]=DFMrgedHomlessWeather["SNWD"]-DFMrgedHomlessWeather["AvgSNWD"]

# %%
DFMrgedHomlessWeather[["Total Adults in Shelter","MOY","PosDiff_TMax","PosDiff_TMIN","PosDiff_PRCP","PosDiff_SNWD"]].tail()
# Out:
#       Total Adults in Shelter  MOY  PosDiff_TMax  PosDiff_TMIN  PosDiff_PRCP  \
# 1072                    36784   12      8.553191      4.010638     -0.145213
# 1073                    36746   12      2.553191      5.010638      0.244787
# 1074                    36609   12      8.553191      5.010638     -0.135213
# 1075                    36324   12      4.553191      7.010638     -0.145213
# 1076                    36560    1    -10.473684    -15.389474     -0.131053
#
#       PosDiff_SNWD
# 1072     -0.046809
# 1073     -0.046809
# 1074     -0.046809
# 1075     -0.046809
# 1076     -2.148421

# %%
DFMrgedHomlessWeather[["DATE","Total Adults in Shelter","MOY","PosDiff_TMax","PosDiff_TMIN","PosDiff_PRCP","PosDiff_SNWD"]].\
sort_values(by=["Total Adults in Shelter","PosDiff_PRCP","PosDiff_SNWD","PosDiff_TMax","PosDiff_TMIN"],ascending=False).\
head(100)
# Out:
#            DATE  Total Adults in Shelter  MOY  PosDiff_TMax  PosDiff_TMIN  \
# 1058 2016-12-15                    36957   12     14.553191     19.010638
# 1057 2016-12-14                    36924   12      6.553191      4.010638
# 1050 2016-12-07                    36910   12      2.553191     -1.989362
# 1030 2016-11-17                    36900   11     -5.543478     -6.728261
# 1048 2016-12-05                    36898   12     -0.446809      0.010638
# 1051 2016-12-08                    36896   12      3.553191      3.010638
# 1062 2016-12-19                    36887   12     17.553191     15.010638
# 1049 2016-12-06                    36884   12      2.553191      1.010638
# 1041 2016-11-28                    36880   11      3.456522      4.271739
# 1056 2016-12-13                    36880   12      5.553191      3.010638
# 1059 2016-12-16                    36874   12     21.553191     21.010638
# 1040 2016-11-27                    36869   11      5.456522      3.271739
# ...

# %%
DFMrgedHomlessWeather.query("PosDiff_PRCP>1")[["Total Individuals in Shelter","MOY"]].\
groupby("MOY").mean()
# Out:
#      Total Individuals in Shelter
# MOY
# 1                    58296.666667
# 2                    53657.500000
# 3                    52328.000000
# 4                    52807.000000
# 5                    55735.000000
# 6                    53549.500000
# 7                    54755.666667
# 8                    56407.000000
# 9                    57206.500000
# 10                   58352.000000
# 11                   59178.000000
# 12                   58394.250000

# %% [markdown]
# DFMrgedHomlessWeather[["DATE","Total Individuals in Shelter","MOY"]]

# %% [markdown]
# DFMrgedHomlessWeather.query("PosDiff_PRCP>1")[["DATE","Total Individuals in Shelter","MOY"]]#.groupby("MOY").mean()

# %%
len(DFMrgedHomlessWeather.query("PosDiff_PRCP>0 or PosDiff_SNWD>0 or PosDiff_TMax> 0 or PosDiff_TMIN>0")[["Total Individuals in Shelter","MOY"]])
# 185137
# Out:
# 732

# %%
DFMrgedHomlessWeather['Family2Total']=DFMrgedHomlessWeather["Total Individuals in Families with Children in Shelter "]/DFMrgedHomlessWeather["Total Individuals in Shelter"]

DG=DFMrgedHomlessWeather.query("(PosDiff_PRCP>0 or PosDiff_SNWD>0 or PosDiff_TMax> 0 or PosDiff_TMIN>0)")[["Family2Total","MOY"]].groupby("MOY").mean() #

# %%
DFMrgedHomlessWeather['Family2Total']=DFMrgedHomlessWeather["Total Individuals in Families with Children in Shelter "]/DFMrgedHomlessWeather["Total Individuals in Shelter"]
DF= DFMrgedHomlessWeather.query("~(PosDiff_PRCP>0 or PosDiff_SNWD>0 or PosDiff_TMax> 0 or PosDiff_TMIN>0)")[["Family2Total","MOY"]].groupby("MOY").mean() #

# %%
DF.columns=["Normal Weather"]

# %%
DF['Severe Weather']=DG

# %%
# %matplotlib notebook
DF.plot(title="Percent of family childeren to total")
# Out:
# <img src="data:image/png;base64,..." width="640">
